# %%
#Importing LIbraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Ques:1: reading the csv
df= pd.read_csv("https://raw.githubusercontent.com/Lordvarun23/MarketingAnalytics/main/Hotel%20Analysis/Sample%20hotel%20data.csv")

# %%
#Ques:2: Display the dataset
df.head()
# Out:
#                          Hotel_Name_City  Review_Overall_Rating  \
# 0                    Bombay Hotel Jaipur                      3
# 1                    Bombay Hotel Jaipur                      1
# 2  Coffea Aroma Resort - Wayanad Meppadi                      2
# 3  Coffea Aroma Resort - Wayanad Meppadi                      3
# 4  Coffea Aroma Resort - Wayanad Meppadi                      3
#
#   date_of_review Month_of_Visit   Review_Type  Rating_Value  Rating_Location  \
# 0      8/26/2014         Aug-14   with family           3.0              4.0
# 1     06-02-2013         Jun-13           NaN           1.0              2.0
# 2     10/20/2014         Oct-14  with friends           2.0              NaN
# 3      9/29/2014         Sep-14  with friends           NaN              4.0
# 4     09-03-2014         Jul-14   as a couple           NaN              NaN
#
#    Rating_Sleep_Quality  Rating_Rooms  Rating_Cleanliness  Rating_Service
# ...

# %%
df.groupby('Hotel_Name_City').agg({('Review_Overall_Rating','Rating_Value'):'mean'})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-deddbe706482> in <module>
# ----> 1 df.groupby('Hotel_Name_City').agg({('Review_Overall_Rating','Rating_Value'):'mean'})
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     977
#     978         op = GroupByApply(self, func, args, kwargs)
# --> 979         result = op.agg()
#     980         if not is_dict_like(func) and result is not None:
#     981             return result
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/apply.py in agg(self)
#     159
#     160         if is_dict_like(arg):
# --> 161             return self.agg_dict_like()
#     162         elif is_list_like(arg):
#     163             # we require a list, but not a 'str'
#
# ...
