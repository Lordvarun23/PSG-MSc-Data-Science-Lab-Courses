# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Read the dataset samplehoteldata.csv

# %%
df = pd.read_csv("Sample hotel data.csv")

# %% [markdown]
# Display the dataset

# %%
df.head()
# Out:
#                          Hotel_Name_City  Review_Overall_Rating  \
# 0                    Bombay Hotel Jaipur                      3
# 1                    Bombay Hotel Jaipur                      1
# 2  Coffea Aroma Resort - Wayanad Meppadi                      2
# 3  Coffea Aroma Resort - Wayanad Meppadi                      3
# 4  Coffea Aroma Resort - Wayanad Meppadi                      3
#
#   date_of_review Month_of_Visit   Review_Type  Rating_Value  Rating_Location  \
# 0      8/26/2014         Aug-14   with family           3.0              4.0
# 1     06-02-2013         Jun-13           NaN           1.0              2.0
# 2     10/20/2014         Oct-14  with friends           2.0              NaN
# 3      9/29/2014         Sep-14  with friends           NaN              4.0
# 4     09-03-2014         Jul-14   as a couple           NaN              NaN
#
#    Rating_Sleep_Quality  Rating_Rooms  Rating_Cleanliness  Rating_Service
# ...

# %% [markdown]
# Find the mean summary for attributes 6 to 11 and display the data set with hotel name

# %%
df.groupby(by="Hotel_Name_City").mean()
# Out:
#                                                 Review_Overall_Rating  \
# Hotel_Name_City
# Bombay Hotel Jaipur                                          2.000000
# Coffea Aroma Resort - Wayanad Meppadi                        4.129630
# Costa Malabari Kannur                                        4.428571
# Duke Palace Mathura                                          2.000000
# Gmvn Tourist Rest House, Syalsaur Rudra_Prayag               4.200000
# Hotel Classic Chandigarh Chandigarh                          3.700000
# Hotel Maya International Srimangala                          3.125000
# Hotel Naveen Regency Chitradurga                             3.200000
# Hotel Prem Bihari Haridwar                                   1.000000
# Hotel Shreenath Palace Jaisalmer                             4.688525
# Hotel Sunrise Mussoorie                                      1.500000
# Kairali Ayurvedic Health Resort Palakkad                     4.078125
# ...

# %%
df.groupby(by="Hotel_Name_City").mean()["Review_Overall_Rating"]>=2.5
# Out:
# Hotel_Name_City
# Bombay Hotel Jaipur                               False
# Coffea Aroma Resort - Wayanad Meppadi              True
# Costa Malabari Kannur                              True
# Duke Palace Mathura                               False
# Gmvn Tourist Rest House, Syalsaur Rudra_Prayag     True
# Hotel Classic Chandigarh Chandigarh                True
# Hotel Maya International Srimangala                True
# Hotel Naveen Regency Chitradurga                   True
# Hotel Prem Bihari Haridwar                        False
# Hotel Shreenath Palace Jaisalmer                   True
# Hotel Sunrise Mussoorie                           False
# Kairali Ayurvedic Health Resort Palakkad           True
# Lotus Nikko Hotel Bodhgaya Bodh_Gaya               True
# Mahua Bagh Resort Kashid                           True
# Midtown Hotel Haridwar                             True
# Panthnivas Rourkela Rourkela                       True
# ...
